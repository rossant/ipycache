# %%
# %load_ext ipycache

# %%
# %%cache plot.pkl
# %matplotlib inline
# import matplotlib.pyplot as plt
# import numpy as np
# print("Hello world!")
# plt.plot(np.random.randn(1000));
# plt.show()
# Out:
# [Skipped the cell's code and loaded variables  from file 'plot.pkl'.]
# Hello world!

# %%
import os
os.remove('plot.pkl')
